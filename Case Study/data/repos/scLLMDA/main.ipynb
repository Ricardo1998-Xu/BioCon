# %%
import warnings
warnings.filterwarnings("ignore")
import scanpy as sc
import pandas as pd
import numpy as np

# %%
# %cd scLLMDA

# %%
# !python main_gene.py

# %%
# !python main_cell.py
# Out:
# Training Epoch 1/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.39it/s]
# Epoch [1/400], Loss: 0.3198
# Training Epoch 2/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.36it/s]
# Epoch [2/400], Loss: 0.1483
# Training Epoch 3/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.31it/s]
# Epoch [3/400], Loss: 0.1385
# Training Epoch 4/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.59it/s]
# Epoch [4/400], Loss: 0.1370
# Training Epoch 5/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.63it/s]
# Epoch [5/400], Loss: 0.1365
# Training Epoch 6/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.82it/s]
# Epoch [6/400], Loss: 0.1362
# Training Epoch 7/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.29it/s]
# Epoch [7/400], Loss: 0.1358
# Training Epoch 8/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.20it/s]
# Epoch [8/400], Loss: 0.1354
# Training Epoch 9/400: 100%|█████████████████████| 64/64 [00:05<00:00, 11.35it/s]
# ...

# %%
# !python main_process.py --train_name 'MosA1'  --test_name 'WholeBrainA'
# Out:
# ['WholeBrainA']
# ['MosA1']

# %%
# %cd ../gda

# %%
# !python gda_demo.py --train_name MosA1  --test_name WholeBrainA
